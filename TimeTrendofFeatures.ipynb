# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame
from matplotlib.pyplot import savefig
from statsmodels.tsa.arima_model import ARIMA
from datetime import datetime
from matplotlib import pyplot
# Import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
import sys
sys.path.insert(0,'../')
# %load_ext autoreload
# %autoreload 2

from sklearn.model_selection import train_test_split
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
Charlotte_11_15_data = pd.read_csv("~/downloads/Data_csv/Mecklenburg_4_years.csv", header = 0)
Charlotte_16_data = pd.read_csv("~/downloads/Data_csv/Charlotte-Mecklenburg_2016.csv", header = 0)

# %% [markdown]
# # show feature names

# %%
print Charlotte_11_15_data.keys();
# Out:
# Index([u'LatLon', u'name', u'NPA', u'Vacant_Land_2015',
#        u'Vacant_Land_Area_2015', u'Commercial_Construction_2015',
#        u'Commercial_Construction_Permitted_Units_2015',
#        u'Commercial_Size_2015', u'Commercial_Size_Total_2015',
#        u'Commercial_Building_Age_2015',
#        ...
#        u'New_Residential_Permit_Units_2016', u'Residential_Renovation_2016',
#        u'Residential_Renovation_Permit_Units_2016', u'Foreclosures_2016',
#        u'Foreclosed_Units_2016', u'Housing_Violations_2016',
#        u'Housing_Violations_Total_2016', u'Street_Connectivity_2016',
#        u'Transit_Proximity_2016', u'Transit_Proximate_Units_2016'],
#       dtype='object', length=135)

# %% [markdown]
# # Select most significant ones

# %%
# for Violent Crime
#select 10 most important features
Transit_Proximity_2015 = Charlotte_11_15_data['Transit_Proximity_2015']
m_Transit_Proximity_2015 = np.mean(Transit_Proximity_2015)

Housing_Violations_2015 = Charlotte_11_15_data['Housing_Violations_2015']
m_Housing_Violations_2015 = np.mean(Housing_Violations_2015)

Housing_Size_2015 = Charlotte_11_15_data['Housing_Size_2015']
m_Housing_Size_2015 = np.mean(Housing_Size_2015)

Street_Connectivity_2015 = Charlotte_11_15_data['Street_Connectivity_2015']
m_Street_Connectivity_2015 = np.mean(Street_Connectivity_2015)

Commercial_Building_Age_2015 = Charlotte_11_15_data['Commercial_Building_Age_2015']
m_Commercial_Building_Age_2015 = np.mean(Commercial_Building_Age_2015)

Residential_Renovation_2015 = Charlotte_11_15_data['Residential_Renovation_2015']
m_Residential_Renovation_2015 = np.mean(Residential_Renovation_2015)

Commercial_Size_Total_2015 = Charlotte_11_15_data['Commercial_Size_Total_2015']
m_Commercial_Size_Total_2015 = np.mean(Commercial_Size_Total_2015)

Transit_Proximate_Units_2015 = Charlotte_11_15_data['Transit_Proximate_Units_2015']
m_Transit_Proximate_Units_2015 = np.mean(Transit_Proximate_Units_2015)

Commercial_Size_2015 = Charlotte_11_15_data['Commercial_Size_2015']
m_Commercial_Size_2015 = np.mean(Commercial_Size_2015)

Housing_Age_2015 = Charlotte_11_15_data['Housing_Age_2015']
m_Housing_Age_2015 = np.mean(Housing_Age_2015)

Transit_Proximity_2016 = Charlotte_11_15_data['Transit_Proximity_2016']
m_Transit_Proximity_2016 = np.mean(Transit_Proximity_2016)

Housing_Violations_2016 = Charlotte_11_15_data['Housing_Violations_2016']
m_Housing_Violations_2016 = np.mean(Housing_Violations_2016)

Housing_Size_2016 = Charlotte_11_15_data['Housing_Size_2016']
m_Housing_Size_2016 = np.mean(Housing_Size_2016)

Street_Connectivity_2016 = Charlotte_11_15_data['Street_Connectivity_2016']
m_Street_Connectivity_2016 = np.mean(Street_Connectivity_2016)

Commercial_Building_Age_2016 = Charlotte_11_15_data['Commercial_Building_Age_2016']
m_Commercial_Building_Age_2016 = np.mean(Commercial_Building_Age_2016)

Residential_Renovation_2016 = Charlotte_11_15_data['Residential_Renovation_2016']
m_Residential_Renovation_2016 = np.mean(Residential_Renovation_2016)

Commercial_Size_Total_2016 = Charlotte_11_15_data['Commercial_Size_Total_2016']
m_Commercial_Size_Total_2016 = np.mean(Commercial_Size_Total_2016)

Transit_Proximate_Units_2016 = Charlotte_11_15_data['Transit_Proximate_Units_2016']
m_Transit_Proximate_Units_2016 = np.mean(Transit_Proximate_Units_2016)

Commercial_Size_2016 = Charlotte_11_15_data['Commercial_Size_2016']
m_Commercial_Size_2016 = np.mean(Commercial_Size_2016)

Housing_Age_2016 = Charlotte_11_15_data['Housing_Age_2016']
m_Housing_Age_2016 = np.mean(Housing_Age_2016)

Transit_Proximity_2013 = Charlotte_11_15_data['Transit_Proximity_2013']
m_Transit_Proximity_2013 = np.mean(Transit_Proximity_2013)

Housing_Violations_2013 = Charlotte_11_15_data['Housing_Violations_2013']
m_Housing_Violations_2013 = np.mean(Housing_Violations_2013)

Housing_Size_2013 = Charlotte_11_15_data['Housing_Size_2013'];
m_Housing_Size_2013 = np.mean(Housing_Size_2013);

Street_Connectivity_2013 = Charlotte_11_15_data['Street_Connectivity_2013'];
m_Street_Connectivity_2013 = np.mean(Street_Connectivity_2013);

Commercial_Building_Age_2013 = Charlotte_11_15_data['Commercial_Building_Age_2013'];
m_Commercial_Building_Age_2013 = np.mean(Commercial_Building_Age_2013);

Residential_Renovation_2013 = Charlotte_11_15_data['Residential_Renovation_2013'];
m_Residential_Renovation_2013 = np.mean(Residential_Renovation_2013);

Commercial_Size_Total_2013 = Charlotte_11_15_data['Commercial_Size_Total_2013'];
m_Commercial_Size_Total_2013 = np.mean(Commercial_Size_Total_2013);

Transit_Proximate_Units_2013 = Charlotte_11_15_data['Transit_Proximate_Units_2013'];
m_Transit_Proximate_Units_2013 = np.mean(Transit_Proximate_Units_2013);

Commercial_Size_2013 = Charlotte_11_15_data['Commercial_Size_2013'];
m_Commercial_Size_2013 = np.mean(Commercial_Size_2013);

Housing_Age_2013 = Charlotte_11_15_data['Housing_Age_2013'];
m_Housing_Age_2013 = np.mean(Housing_Age_2013);


Transit_Proximity_2011 = Charlotte_11_15_data['Transit_Proximity_2011'];
m_Transit_Proximity_2011 = np.mean(Transit_Proximity_2011);

Housing_Violations_2011 = Charlotte_11_15_data['Housing_Violations_2011'];
m_Housing_Violations_2011 = np.mean(Housing_Violations_2011);

Housing_Size_2011 = Charlotte_11_15_data['Housing_Size_2011'];
m_Housing_Size_2011 = np.mean(Housing_Size_2011);

Street_Connectivity_2011 = Charlotte_11_15_data['Street_Connectivity_2011'];
m_Street_Connectivity_2011 = np.mean(Street_Connectivity_2011);

Commercial_Building_Age_2011 = Charlotte_11_15_data['Commercial_Building_Age_2011'];
m_Commercial_Building_Age_2011 = np.mean(Commercial_Building_Age_2011);

Residential_Renovation_2011 = Charlotte_11_15_data['Residential_Renovation_2011'];
m_Residential_Renovation_2011 = np.mean(Residential_Renovation_2011);

Commercial_Size_Total_2011 = Charlotte_11_15_data['Commercial_Size_Total_2011']
m_Commercial_Size_Total_2011 = np.mean(Commercial_Size_Total_2011)

Transit_Proximate_Units_2011 = Charlotte_11_15_data['Transit_Proximate_Units_2011']
m_Transit_Proximate_Units_2011 = np.mean(Transit_Proximate_Units_2011)

Commercial_Size_2011 = Charlotte_11_15_data['Commercial_Size_2011']
m_Commercial_Size_2011 = np.mean(Commercial_Size_2011)

Housing_Age_2011 = Charlotte_11_15_data['Housing_Age_2011']
m_Housing_Age_2011 = np.mean(Housing_Age_2011)

TimeSeries_Transit_Proximity = [m_Transit_Proximity_2011,m_Transit_Proximity_2013,m_Transit_Proximity_2015,m_Transit_Proximity_2016]
TimeSeries_Housing_Violations = [m_Housing_Violations_2011,m_Housing_Violations_2013,m_Housing_Violations_2015,m_Housing_Violations_2016]
TimeSeries_Housing_Size = [m_Housing_Size_2011,m_Housing_Size_2013,m_Housing_Size_2015,m_Housing_Size_2016]
TimeSeries_Street_Connectivity = [m_Street_Connectivity_2011,m_Street_Connectivity_2013,m_Street_Connectivity_2015,m_Street_Connectivity_2016]
TimeSeries_Commercial_Building_Age = [m_Commercial_Building_Age_2011,m_Commercial_Building_Age_2013,m_Commercial_Building_Age_2015,m_Commercial_Building_Age_2016]
TimeSeries_Residential_Renovation = [m_Residential_Renovation_2011,m_Residential_Renovation_2013,m_Residential_Renovation_2015,m_Residential_Renovation_2016]
TimeSeries_Commercial_Size_Total = [m_Commercial_Size_Total_2011,m_Commercial_Size_Total_2013,m_Commercial_Size_Total_2015,m_Commercial_Size_Total_2016]
TimeSeries_Transit_Proximate_Units = [m_Transit_Proximate_Units_2011,m_Transit_Proximate_Units_2013,m_Transit_Proximate_Units_2015,m_Transit_Proximate_Units_2016]
TimeSeries_Commercial_Size = [m_Commercial_Size_2011,m_Commercial_Size_2013,m_Commercial_Size_2015,m_Commercial_Size_2016]
TimeSeries_Housing_Age = [m_Housing_Age_2011,m_Housing_Age_2013,m_Housing_Age_2015,m_Housing_Age_2016]

x = [2011,2013,2015,2016]
f, axarr = plt.subplots(5, sharex=True)
axarr[0].plot(x, TimeSeries_Transit_Proximity)
axarr[0].set_title('TimeSeries on Transit_Proximity')
#axarr[0].ylabel('Trasit_Proximity')
axarr[1].set_title('TimeSeries on Housing_Violations')
axarr[1].plot(x, TimeSeries_Housing_Violations)

axarr[2].set_title('TimeSeries on Housing_Size')
axarr[2].plot(x, TimeSeries_Housing_Size)

axarr[3].set_title('TimeSeries on Street_Connectivity')
axarr[3].plot(x, TimeSeries_Street_Connectivity)

axarr[4].set_title('TimeSeries on Commercial_Building_Age')
axarr[4].plot(x, TimeSeries_Commercial_Building_Age)
savefig('timeSeries1.png')
f2, axarr2 = plt.subplots(5, sharex=True)

axarr2[0].set_title('TimeSeries on Residential_Renovation')
axarr2[0].plot(x, TimeSeries_Residential_Renovation)

axarr2[1].set_title('TimeSeries on Commercial_Size_Total')
axarr2[1].plot(x, TimeSeries_Commercial_Size_Total)

axarr2[2].set_title('TimeSeries on Transit_Proximate_Units')
axarr2[2].plot(x, TimeSeries_Transit_Proximate_Units)

axarr2[3].set_title('TimeSeries on Commercial_Size')
axarr2[3].plot(x, TimeSeries_Commercial_Size)

axarr2[4].set_title('TimeSeries on Housing_Age')
axarr2[4].plot(x, TimeSeries_Housing_Age)

savefig('timeSeries2.png')
#axarr[1].xlabel('years')

# %% [markdown]
# # Time Series Analysis

# %% [markdown]
# ## Housing_Size

# %%
m_Housing_Size_2012 = (m_Housing_Size_2011+m_Housing_Size_2013)/2
m_Housing_Size_2014 = (m_Housing_Size_2013+m_Housing_Size_2015)/2
dic_Housing_Size = {'2011':m_Housing_Size_2011,'2012':m_Housing_Size_2012,'2013': m_Housing_Size_2013,'2014':m_Housing_Size_2014,'2015':m_Housing_Size_2015,'2016':m_Housing_Size_2016}
Series_Housing_Size = Series(dic_Housing_Size)
model = ARIMA(Series_Housing_Size, order=(1,0,0))
model_fit = model.fit(disp=-1)
print(model_fit.summary())


#plot time Series
plt.plot(Series_Housing_Size,label = 'Original')
plt.plot(model_fit.fittedvalues, color='red',label = 'ARIMA')
plt.title('Time Series of Housing_Size')
savefig('TS_Housing_Size.png')
# plot residual errors
#residuals = DataFrame(model_fit.resid)
#residuals.plot()

#plt.show()
#residuals.plot(kind='kde')
#savefig('residual.png')
#plt.show()
#print(residuals.describe())
# Out:
#                               ARMA Model Results
# ...
# Dep. Variable:                      y   No. Observations:                    6
# Model:                     ARMA(1, 0)   Log Likelihood                 -22.894
# Method:                       css-mle   S.D. of innovations             10.020
# Date:                Fri, 08 Dec 2017   AIC                             51.789
# Time:                        01:39:00   BIC                             51.164
# Sample:                    01-01-2011   HQIC                            49.288
#                          - 01-01-2016
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1943.8647     14.249    136.422      0.000    1915.937    1971.792
# ar.L1.y        0.8182      0.259      3.153      0.034       0.310       1.327
#                                     Roots
# ...

# %% [markdown]
# ## Transit_Proximity

# %%
m_Transit_Proximity_2012 = (m_Transit_Proximity_2011+m_Transit_Proximity_2013)/2
m_Transit_Proximity_2014 = (m_Transit_Proximity_2013+m_Transit_Proximity_2015)/2
dic_Transit_Proximity = {'2011':m_Transit_Proximity_2011,'2012':m_Transit_Proximity_2012,'2013': m_Transit_Proximity_2013,'2014':m_Transit_Proximity_2014,'2015':m_Transit_Proximity_2015,'2016':m_Transit_Proximity_2016}
Series_Transit_Proximity = Series(dic_Transit_Proximity)
model = ARIMA(Series_Transit_Proximity, order=(1,0,0))
model_fit = model.fit(disp=-1)
print(model_fit.summary())


#plot time Series
plt.plot(Series_Transit_Proximity,label = 'Original')
plt.plot(model_fit.fittedvalues, color='red',label = 'ARIMA')
plt.title('Time Series of Transit_Proximity')
savefig('TS_Transit_Proximity.png')
# Out:
#                               ARMA Model Results
# ...
# Dep. Variable:                      y   No. Observations:                    6
# Model:                     ARMA(1, 0)   Log Likelihood                  -1.000
# Method:                       css-mle   S.D. of innovations              0.285
# Date:                Fri, 08 Dec 2017   AIC                              7.999
# Time:                        01:38:44   BIC                              7.374
# Sample:                    01-01-2011   HQIC                             5.498
#                          - 01-01-2016
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         66.2053      0.155    427.014      0.000      65.901      66.509
# ar.L1.y        0.2234      0.510      0.438      0.684      -0.777       1.224
#                                     Roots
# ...

# %% [markdown]
# ## Housing_Violations

# %%
m_Housing_Violations_2012 = (m_Housing_Violations_2011+m_Housing_Violations_2013)/2
m_Housing_Violations_2014 = (m_Housing_Violations_2013+m_Housing_Violations_2015)/2
dic_Housing_Violations = {'2011':m_Housing_Violations_2011,'2012':m_Housing_Violations_2012,'2013': m_Housing_Violations_2013,'2014':m_Housing_Violations_2014,'2015':m_Housing_Violations_2015,'2016':m_Housing_Violations_2016}
Series_Housing_Violations = Series(dic_Housing_Violations)
model = ARIMA(Series_Housing_Violations, order=(1,0,0))
model_fit = model.fit(disp=-1)
print(model_fit.summary())


#plot time Series
plt.plot(Series_Housing_Violations,label = 'Original')
plt.plot(model_fit.fittedvalues, color='red',label = 'ARIMA')
plt.title('Time Series of Housing_Violations')
savefig('TS_Housing_Violations.png')
# Out:
#                               ARMA Model Results
# ...
# Dep. Variable:                      y   No. Observations:                    6
# Model:                     ARMA(1, 0)   Log Likelihood                   5.050
# Method:                       css-mle   S.D. of innovations              0.099
# Date:                Fri, 08 Dec 2017   AIC                             -4.100
# Time:                        01:38:29   BIC                             -4.725
# Sample:                    01-01-2011   HQIC                            -6.601
#                          - 01-01-2016
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6244      0.102      6.120      0.004       0.424       0.824
# ar.L1.y        0.6693      0.332      2.013      0.114       0.018       1.321
#                                     Roots
# ...

# %% [markdown]
# ## Street_Connectivity

# %%
m_Street_Connectivity_2012 = (m_Street_Connectivity_2011+m_Street_Connectivity_2013)/2
m_Street_Connectivity_2014 = (m_Street_Connectivity_2013+m_Street_Connectivity_2015)/2
dic_Street_Connectivity = {'2011':m_Street_Connectivity_2011,'2012':m_Street_Connectivity_2012,'2013': m_Street_Connectivity_2013,'2014':m_Street_Connectivity_2014,'2015':m_Street_Connectivity_2015,'2016':m_Street_Connectivity_2016}
Series_Street_Connectivity = Series(dic_Street_Connectivity)
model = ARIMA(Series_Street_Connectivity, order=(1,0,0))
model_fit = model.fit(disp=-1)
print(model_fit.summary())


#plot time Series
plt.plot(Series_Street_Connectivity,label = 'Original')
plt.plot(model_fit.fittedvalues, color='red',label = 'ARIMA')
plt.title('Time Series of Street_Connectivity')
savefig('TS_Street_Connectivity.png')
# Out:
#                               ARMA Model Results
# ...
# Dep. Variable:                      y   No. Observations:                    6
# Model:                     ARMA(1, 0)   Log Likelihood                   4.763
# Method:                       css-mle   S.D. of innovations              0.104
# Date:                Fri, 08 Dec 2017   AIC                             -3.526
# Time:                        01:42:14   BIC                             -4.150
# Sample:                    01-01-2011   HQIC                            -6.027
#                          - 01-01-2016
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.0512      0.107      9.788      0.001       0.841       1.262
# ar.L1.y        0.6799      0.356      1.911      0.129      -0.017       1.377
#                                     Roots
# ...

# %% [markdown]
# ## Commercial_Building_Age

# %%
m_Commercial_Building_Age_2012 = (m_Commercial_Building_Age_2011+m_Commercial_Building_Age_2013)/2
m_Commercial_Building_Age_2014 = (m_Commercial_Building_Age_2013+m_Commercial_Building_Age_2015)/2
dic_Commercial_Building_Age = {'2011':m_Commercial_Building_Age_2011,'2012':m_Commercial_Building_Age_2012,'2013': m_Commercial_Building_Age_2013,'2014':m_Commercial_Building_Age_2014,'2015':m_Commercial_Building_Age_2015,'2016':m_Commercial_Building_Age_2016}
Series_Commercial_Building_Age = Series(dic_Commercial_Building_Age)
model = ARIMA(Series_Commercial_Building_Age, order=(1,0,0))
model_fit = model.fit(disp=-1)
print(model_fit.summary())


#plot time Series
plt.plot(Series_Commercial_Building_Age,label = 'Original')
plt.plot(model_fit.fittedvalues, color='red',label = 'ARIMA')
plt.title('Time Series of Commercial_Building_Age')
savefig('TS_Commercial_Building_Age.png')
# Out:
#                               ARMA Model Results
# ...
# Dep. Variable:                      y   No. Observations:                    6
# Model:                     ARMA(1, 0)   Log Likelihood                  -7.414
# Method:                       css-mle   S.D. of innovations              0.730
# Date:                Fri, 08 Dec 2017   AIC                             20.828
# Time:                        01:44:43   BIC                             20.203
# Sample:                    01-01-2011   HQIC                            18.327
#                          - 01-01-2016
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         28.5979      1.420     20.135      0.000      25.814      31.382
# ar.L1.y        0.8916      0.155      5.744      0.005       0.587       1.196
#                                     Roots
# ...

# %% [markdown]
# ## Residential_Renovation

# %%
m_Residential_Renovation_2012 = (m_Residential_Renovation_2011+m_Residential_Renovation_2013)/2
m_Residential_Renovation_2014 = (m_Residential_Renovation_2013+m_Residential_Renovation_2015)/2
dic_Residential_Renovation = {'2011':m_Residential_Renovation_2011,'2012':m_Residential_Renovation_2012,'2013': m_Residential_Renovation_2013,'2014':m_Residential_Renovation_2014,'2015':m_Residential_Renovation_2015,'2016':m_Residential_Renovation_2016}
Series_Residential_Renovation = Series(dic_Residential_Renovation)
model = ARIMA(Series_Residential_Renovation, order=(1,0,0))
model_fit = model.fit(disp=-1)
print(model_fit.summary())


#plot time Series
plt.plot(Series_Residential_Renovation,label = 'Original')
plt.plot(model_fit.fittedvalues, color='red',label = 'ARIMA')
plt.title('Time Series of Residential_Renovation')
savefig('TS_Residential_Renovation.png')
# Out:
# /Users/arielxiao/anaconda/lib/python2.7/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:649: RuntimeWarning: divide by zero encountered in divide
#   R_mat, T_mat)
#                               ARMA Model Results
# ...
# Dep. Variable:                      y   No. Observations:                    6
# Model:                     ARMA(1, 0)   Log Likelihood                  -0.918
# Method:                       css-mle   S.D. of innovations              0.256
# Date:                Fri, 08 Dec 2017   AIC                              7.836
# Time:                        01:51:02   BIC                              7.212
# Sample:                    01-01-2011   HQIC                             5.335
#                          - 01-01-2016
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.4109      0.383      6.301      0.003       1.661       3.161
# ...

# %% [markdown]
# ## Commercial_Size_Total

# %%
m_Commercial_Size_Total_2012 = (m_Commercial_Size_Total_2011+m_Commercial_Size_Total_2013)/2
m_Commercial_Size_Total_2014 = (m_Commercial_Size_Total_2013+m_Commercial_Size_Total_2015)/2
dic_Commercial_Size_Total = {'2011':m_Commercial_Size_Total_2011,'2012':m_Commercial_Size_Total_2012,'2013': m_Commercial_Size_Total_2013,'2014':m_Commercial_Size_Total_2014,'2015':m_Commercial_Size_Total_2015,'2016':m_Commercial_Size_Total_2016}
Series_Commercial_Size_Total = Series(dic_Commercial_Size_Total)
model = ARIMA(Series_Commercial_Size_Total, order=(1,0,0))
model_fit = model.fit(disp=-1)
print(model_fit.summary())

#plot time Series
plt.plot(Series_Commercial_Size_Total,label = 'Original')
plt.plot(model_fit.fittedvalues, color='red',label = 'ARIMA')
plt.title('Time Series of Commercial_Size_Total')
savefig('TS_Commercial_Size_Total.png')
# Out:
#                               ARMA Model Results
# ...
# Dep. Variable:                      y   No. Observations:                    6
# Model:                     ARMA(1, 0)   Log Likelihood                 -62.093
# Method:                       css-mle   S.D. of innovations           7127.937
# Date:                Fri, 08 Dec 2017   AIC                            130.187
# Time:                        01:55:46   BIC                            129.562
# Sample:                    01-01-2011   HQIC                           127.686
#                          - 01-01-2016
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       7.484e+05   7447.716    100.482      0.000    7.34e+05    7.63e+05
# ar.L1.y        0.7088      0.390      1.820      0.143      -0.055       1.472
#                                     Roots
# ...

# %% [markdown]
# ## Transit_Proximate_Units

# %%
m_Transit_Proximate_Units_2012 = (m_Transit_Proximate_Units_2011+m_Transit_Proximate_Units_2013)/2
m_Transit_Proximate_Units_2014 = (m_Transit_Proximate_Units_2013+m_Transit_Proximate_Units_2015)/2
dic_Transit_Proximate_Units = {'2011':m_Transit_Proximate_Units_2011,'2012':m_Transit_Proximate_Units_2012,'2013': m_Transit_Proximate_Units_2013,'2014':m_Transit_Proximate_Units_2014,'2015':m_Transit_Proximate_Units_2015,'2016':m_Transit_Proximate_Units_2016}
Series_Transit_Proximate_Units = Series(dic_Transit_Proximate_Units)
model = ARIMA(Series_Transit_Proximate_Units, order=(1,0,0))
model_fit = model.fit(disp=-1)
print(model_fit.summary())


#plot time Series
plt.plot(Series_Transit_Proximate_Units,label = 'Original')
plt.plot(model_fit.fittedvalues, color='red',label = 'ARIMA')
plt.title('Time Series of Transit_Proximate_Units')
savefig('TS_Transit_Proximate_Units.png')
# Out:
#                               ARMA Model Results
# ...
# Dep. Variable:                      y   No. Observations:                    6
# Model:                     ARMA(1, 0)   Log Likelihood                 -21.525
# Method:                       css-mle   S.D. of innovations              7.894
# Date:                Fri, 08 Dec 2017   AIC                             49.051
# Time:                        01:58:09   BIC                             48.426
# Sample:                    01-01-2011   HQIC                            46.550
#                          - 01-01-2016
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        594.9681     12.222     48.679      0.000     571.013     618.923
# ar.L1.y        0.8412      0.225      3.731      0.020       0.399       1.283
#                                     Roots
# ...

# %% [markdown]
# ## Commercial_Size

# %%
m_Commercial_Size_2012 = (m_Commercial_Size_2011+m_Commercial_Size_2013)/2
m_Commercial_Size_2014 = (m_Commercial_Size_2013+m_Commercial_Size_2015)/2
dic_Commercial_Size = {'2011':m_Commercial_Size_2011,'2012':m_Commercial_Size_2012,'2013': m_Commercial_Size_2013,'2014':m_Commercial_Size_2014,'2015':m_Commercial_Size_2015,'2016':m_Commercial_Size_2016}
Series_Commercial_Size = Series(dic_Commercial_Size)
model = ARIMA(Series_Commercial_Size, order=(1,0,0))
model_fit = model.fit(disp=-1)
print(model_fit.summary())


#plot time Series
plt.plot(Series_Commercial_Size,label = 'Original')
plt.plot(model_fit.fittedvalues, color='red',label = 'ARIMA')
plt.title('Time Series of Commercial_Size')
savefig('TS_Commercial_Size.png')
# Out:
#                               ARMA Model Results
# ...
# Dep. Variable:                      y   No. Observations:                    6
# Model:                     ARMA(1, 0)   Log Likelihood                 -46.724
# Method:                       css-mle   S.D. of innovations            572.399
# Date:                Fri, 08 Dec 2017   AIC                             99.449
# Time:                        02:00:47   BIC                             98.824
# Sample:                    01-01-2011   HQIC                            96.948
#                          - 01-01-2016
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.354e+04    392.673     59.958      0.000    2.28e+04    2.43e+04
# ar.L1.y        0.4476      0.671      0.667      0.541      -0.868       1.763
#                                     Roots
# ...

# %% [markdown]
# ## Housing_Age

# %%
m_Housing_Age_2012 = (m_Housing_Age_2011+m_Housing_Age_2013)/2
m_Housing_Age_2014 = (m_Housing_Age_2013+m_Housing_Age_2015)/2
dic_Housing_Age = {'2011':m_Housing_Age_2011,'2012':m_Housing_Age_2012,'2013': m_Housing_Age_2013,'2014':m_Housing_Age_2014,'2015':m_Housing_Age_2015,'2016':m_Housing_Age_2016}
Series_Housing_Age = Series(dic_Housing_Age)
model = ARIMA(Series_Housing_Age, order=(1,0,0))
model_fit = model.fit(disp=-1)
print(model_fit.summary())


#plot time Series
plt.plot(Series_Housing_Age,label = 'Original')
plt.plot(model_fit.fittedvalues, color='red',label = 'ARIMA')
plt.title('Time Series of Housing_Age')
savefig('TS_Housing_Age.png')
# Out:
#                               ARMA Model Results
# ...
# Dep. Variable:                      y   No. Observations:                    6
# Model:                     ARMA(1, 0)   Log Likelihood                  -6.947
# Method:                       css-mle   S.D. of innovations              0.675
# Date:                Fri, 08 Dec 2017   AIC                             19.894
# Time:                        02:03:29   BIC                             19.269
# Sample:                    01-01-2011   HQIC                            17.393
#                          - 01-01-2016
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         31.2834      1.316     23.774      0.000      28.704      33.862
# ar.L1.y        0.8919      0.155      5.749      0.005       0.588       1.196
#                                     Roots
# ...
